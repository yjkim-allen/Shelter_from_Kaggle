# %%
import pandas as pd
import re
import matplotlib as plt
import numpy as np
from datetime import *

from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import log_loss

import xgboost as xgb
from xgboost.sklearn import XGBClassifier
from sklearn.cross_validation import cross_val_score
from sklearn.grid_search import GridSearchCV
from sklearn import cross_validation
# %matplotlib inline
# Out:
# C:\Python36\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Python36\lib\site-packages\sklearn\grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
# Read the dataset
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# Merge dataset : Train + Test // drop unnecessary features
dataset = train.drop(['AnimalID', 'OutcomeSubtype', 'OutcomeType', 'DateTime'], axis=1)
dataset = dataset.append(test.drop(['ID', 'DateTime'], axis=1), ignore_index=True)
print(train.shape, test.shape, dataset.shape)
# Out:
# (26729, 10) (11456, 8) (38185, 6)

# %%
dataset.tail()
# Out:
#         Name AnimalType SexuponOutcome AgeuponOutcome                   Breed  \
# 38180    NaN        Cat  Neutered Male       2 months  Domestic Shorthair Mix
# 38181    NaN        Cat  Intact Female        2 weeks  Domestic Shorthair Mix
# 38182    NaN        Cat  Intact Female         1 year  Domestic Shorthair Mix
# 38183  Rambo        Dog  Neutered Male        6 years     German Shepherd Mix
# 38184  Gusto        Dog    Intact Male        4 years      Labrador Retriever
#
#            Color
# 38180      Black
# 38181       Blue
# 38182     Calico
# 38183  Black/Tan
# 38184      Cream

# %%
dataset.isnull().sum()
# Out:
# Name              10916
# AnimalType            0
# SexuponOutcome        1
# AgeuponOutcome       24
# Breed                 0
# Color                 0
# dtype: int64

# %%
#calculate Age in days
def calculate_age(x):
    if pd.isnull(x):
        return x
    num = int(x.split(' ')[0])
    if 'year' in x:
        return num * 365
    elif 'month' in x:
        return num * 30
    elif 'week' in x:
        return num * 7
    
def has_name(x):
    if pd.isnull(x):
        return 0
    return 1

def is_mix(x):
    if 'Mix' in x:
        return 1
    return 0

# %%
#data transformation

dataset['AgeuponOutcome'] = dataset['AgeuponOutcome'].apply(lambda x : calculate_age(x))
dataset['AgeuponOutcome'].fillna(dataset['AgeuponOutcome'].dropna().mean(), inplace=True)

dataset.tail()
# Out:
#         Name AnimalType SexuponOutcome  AgeuponOutcome  \
# 38180    NaN        Cat  Neutered Male            60.0
# 38181    NaN        Cat  Intact Female            14.0
# 38182    NaN        Cat  Intact Female           365.0
# 38183  Rambo        Dog  Neutered Male          2190.0
# 38184  Gusto        Dog    Intact Male          1460.0
#
#                         Breed      Color
# 38180  Domestic Shorthair Mix      Black
# 38181  Domestic Shorthair Mix       Blue
# 38182  Domestic Shorthair Mix     Calico
# 38183     German Shepherd Mix  Black/Tan
# 38184      Labrador Retriever      Cream

# %%
# Since there is only one NA, I will assign it to maximum class
dataset['SexuponOutcome'].fillna('Neutered Male', inplace=True)

dataset.tail()
# Out:
#         Name AnimalType SexuponOutcome  AgeuponOutcome  \
# 38180    NaN        Cat  Neutered Male            60.0
# 38181    NaN        Cat  Intact Female            14.0
# 38182    NaN        Cat  Intact Female           365.0
# 38183  Rambo        Dog  Neutered Male          2190.0
# 38184  Gusto        Dog    Intact Male          1460.0
#
#                         Breed      Color
# 38180  Domestic Shorthair Mix      Black
# 38181  Domestic Shorthair Mix       Blue
# 38182  Domestic Shorthair Mix     Calico
# 38183     German Shepherd Mix  Black/Tan
# 38184      Labrador Retriever      Cream

# %%
# Does Animal has a name?
dataset['HasName'] = dataset['Name'].apply(has_name)

dataset.tail()
# Out:
#         Name AnimalType SexuponOutcome  AgeuponOutcome  \
# 38180    NaN        Cat  Neutered Male            60.0
# 38181    NaN        Cat  Intact Female            14.0
# 38182    NaN        Cat  Intact Female           365.0
# 38183  Rambo        Dog  Neutered Male          2190.0
# 38184  Gusto        Dog    Intact Male          1460.0
#
#                         Breed      Color  HasName
# 38180  Domestic Shorthair Mix      Black        0
# 38181  Domestic Shorthair Mix       Blue        0
# 38182  Domestic Shorthair Mix     Calico        0
# 38183     German Shepherd Mix  Black/Tan        1
# 38184      Labrador Retriever      Cream        1

# %%
# Is animal of mix breed?
dataset['IsMix'] = dataset['Breed'].apply(is_mix)

dataset.tail()
# Out:
#         Name AnimalType SexuponOutcome  AgeuponOutcome  \
# 38180    NaN        Cat  Neutered Male            60.0
# 38181    NaN        Cat  Intact Female            14.0
# 38182    NaN        Cat  Intact Female           365.0
# 38183  Rambo        Dog  Neutered Male          2190.0
# 38184  Gusto        Dog    Intact Male          1460.0
#
#                         Breed      Color  HasName  IsMix
# 38180  Domestic Shorthair Mix      Black        0      1
# 38181  Domestic Shorthair Mix       Blue        0      1
# 38182  Domestic Shorthair Mix     Calico        0      1
# 38183     German Shepherd Mix  Black/Tan        1      1
# 38184      Labrador Retriever      Cream        1      0

# %%
# Break SexuponOutcome into two - Sterilized and Sex
sex = dataset['SexuponOutcome'].str.split(' ', expand=True)
dataset['Sterilized'] = sex[0]
dataset['Sterilized'].fillna('Unknown', inplace=True)
dataset['Sex'] = sex[1]
dataset['Sex'].fillna('Unknown', inplace=True)

dataset.tail()
# Out:
#         Name AnimalType SexuponOutcome  AgeuponOutcome  \
# 38180    NaN        Cat  Neutered Male            60.0
# 38181    NaN        Cat  Intact Female            14.0
# 38182    NaN        Cat  Intact Female           365.0
# 38183  Rambo        Dog  Neutered Male          2190.0
# 38184  Gusto        Dog    Intact Male          1460.0
#
#                         Breed      Color  HasName  IsMix Sterilized     Sex
# 38180  Domestic Shorthair Mix      Black        0      1   Neutered    Male
# 38181  Domestic Shorthair Mix       Blue        0      1     Intact  Female
# 38182  Domestic Shorthair Mix     Calico        0      1     Intact  Female
# 38183     German Shepherd Mix  Black/Tan        1      1   Neutered    Male
# 38184      Labrador Retriever      Cream        1      0     Intact    Male

# %%
# Making cols about Breeds

dataset['Breed_New'] = dataset['Breed'].apply(lambda x: x.split(' Mix')[0])
breeds = dataset['Breed_New'].apply(lambda x : x.split('/'))
dataset['Breed_1'] = breeds.apply(lambda x : x[0])

# Instead of Breed_2, I will use Multiple_Breeds feature
dataset['Multiple_Breeds'] = dataset['Breed'].apply(lambda x : 1 if '/' in x else 0)

dataset.tail()
# Out:
#         Name AnimalType SexuponOutcome  AgeuponOutcome  \
# 38180    NaN        Cat  Neutered Male            60.0
# 38181    NaN        Cat  Intact Female            14.0
# 38182    NaN        Cat  Intact Female           365.0
# 38183  Rambo        Dog  Neutered Male          2190.0
# 38184  Gusto        Dog    Intact Male          1460.0
#
#                         Breed      Color  HasName  IsMix Sterilized     Sex  \
# 38180  Domestic Shorthair Mix      Black        0      1   Neutered    Male
# 38181  Domestic Shorthair Mix       Blue        0      1     Intact  Female
# 38182  Domestic Shorthair Mix     Calico        0      1     Intact  Female
# 38183     German Shepherd Mix  Black/Tan        1      1   Neutered    Male
# 38184      Labrador Retriever      Cream        1      0     Intact    Male
#
#                 Breed_New             Breed_1  Multiple_Breeds
# 38180  Domestic Shorthair  Domestic Shorthair                0
# 38181  Domestic Shorthair  Domestic Shorthair                0
# 38182  Domestic Shorthair  Domestic Shorthair                0
# 38183     German Shepherd     German Shepherd                0
# 38184  Labrador Retriever  Labrador Retriever                0

# %%
# Making cols about Colors

colors = dataset['Color'].apply(lambda x : x.split('/'))
dataset['Color_1'] = colors.apply(lambda x : x[0].split(' ')[0])

# Instead of Color_2, I will use Multiple_Colors feature
dataset['Multiple_Colors'] = dataset['Color'].apply(lambda x : 1 if '/' in x else 0)

dataset.tail()
# Out:
#         Name AnimalType SexuponOutcome  AgeuponOutcome  \
# 38180    NaN        Cat  Neutered Male            60.0
# 38181    NaN        Cat  Intact Female            14.0
# 38182    NaN        Cat  Intact Female           365.0
# 38183  Rambo        Dog  Neutered Male          2190.0
# 38184  Gusto        Dog    Intact Male          1460.0
#
#                         Breed      Color  HasName  IsMix Sterilized     Sex  \
# 38180  Domestic Shorthair Mix      Black        0      1   Neutered    Male
# 38181  Domestic Shorthair Mix       Blue        0      1     Intact  Female
# 38182  Domestic Shorthair Mix     Calico        0      1     Intact  Female
# 38183     German Shepherd Mix  Black/Tan        1      1   Neutered    Male
# 38184      Labrador Retriever      Cream        1      0     Intact    Male
#
#                 Breed_New             Breed_1  Multiple_Breeds Color_1  \
# 38180  Domestic Shorthair  Domestic Shorthair                0   Black
# 38181  Domestic Shorthair  Domestic Shorthair                0    Blue
# 38182  Domestic Shorthair  Domestic Shorthair                0  Calico
# 38183     German Shepherd     German Shepherd                0   Black
# 38184  Labrador Retriever  Labrador Retriever                0   Cream
#
#        Multiple_Colors
# 38180                0
# 38181                0
# 38182                0
# 38183                1
# 38184                0

# %%
# Encoding
enc = LabelEncoder()
dataset['Color_1'] = enc.fit_transform(dataset['Color_1'])
dataset['Breed_1'] = enc.fit_transform(dataset['Breed_1'])

dataset.tail()
# Out:
#         Name AnimalType SexuponOutcome  AgeuponOutcome  \
# 38180    NaN        Cat  Neutered Male            60.0
# 38181    NaN        Cat  Intact Female            14.0
# 38182    NaN        Cat  Intact Female           365.0
# 38183  Rambo        Dog  Neutered Male          2190.0
# 38184  Gusto        Dog    Intact Male          1460.0
#
#                         Breed      Color  HasName  IsMix Sterilized     Sex  \
# 38180  Domestic Shorthair Mix      Black        0      1   Neutered    Male
# 38181  Domestic Shorthair Mix       Blue        0      1     Intact  Female
# 38182  Domestic Shorthair Mix     Calico        0      1     Intact  Female
# 38183     German Shepherd Mix  Black/Tan        1      1   Neutered    Male
# 38184      Labrador Retriever      Cream        1      0     Intact    Male
#
#                 Breed_New  Breed_1  Multiple_Breeds  Color_1  Multiple_Colors
# 38180  Domestic Shorthair       85                0        2                0
# 38181  Domestic Shorthair       85                0        3                0
# 38182  Domestic Shorthair       85                0        6                0
# 38183     German Shepherd      104                0        2                1
# 38184  Labrador Retriever      131                0        8                0

# %%
# Dummy Columns
dummy_columns = ['Sterilized', 'Sex']
dataset = pd.get_dummies(dataset, columns=dummy_columns)

dataset.tail()
# Out:
#         Name AnimalType SexuponOutcome  AgeuponOutcome  \
# 38180    NaN        Cat  Neutered Male            60.0
# 38181    NaN        Cat  Intact Female            14.0
# 38182    NaN        Cat  Intact Female           365.0
# 38183  Rambo        Dog  Neutered Male          2190.0
# 38184  Gusto        Dog    Intact Male          1460.0
#
#                         Breed      Color  HasName  IsMix           Breed_New  \
# 38180  Domestic Shorthair Mix      Black        0      1  Domestic Shorthair
# 38181  Domestic Shorthair Mix       Blue        0      1  Domestic Shorthair
# 38182  Domestic Shorthair Mix     Calico        0      1  Domestic Shorthair
# 38183     German Shepherd Mix  Black/Tan        1      1     German Shepherd
# 38184      Labrador Retriever      Cream        1      0  Labrador Retriever
#
#        Breed_1  Multiple_Breeds  Color_1  Multiple_Colors  Sterilized_Intact  \
# 38180       85                0        2                0                  0
# 38181       85                0        3                0                  1
# 38182       85                0        6                0                  1
# 38183      104                0        2                1                  0
# 38184      131                0        8                0                  1
#
#        Sterilized_Neutered  Sterilized_Spayed  Sterilized_Unknown  Sex_Female  \
# 38180                    1                  0                   0           0
# 38181                    0                  0                   0           1
# 38182                    0                  0                   0           1
# 38183                    1                  0                   0           0
# 38184                    0                  0                   0           0
#
#        Sex_Male  Sex_Unknown
# 38180         1            0
# 38181         0            0
# 38182         0            0
# 38183         1            0
# 38184         1            0

# %%
# Drop unnecessary columns
drop_columns = ['Name', 'SexuponOutcome', 'Breed', 'Color', 'Breed_New', 'AnimalType']
dataset = dataset.drop(drop_columns, axis=1)

print(train.shape, test.shape, dataset.shape)

dataset.tail()
# Out:
# (26729, 10) (11456, 8) (38185, 14)
#        AgeuponOutcome  HasName  IsMix  Breed_1  Multiple_Breeds  Color_1  \
# 38180            60.0        0      1       85                0        2
# 38181            14.0        0      1       85                0        3
# 38182           365.0        0      1       85                0        6
# 38183          2190.0        1      1      104                0        2
# 38184          1460.0        1      0      131                0        8
#
#        Multiple_Colors  Sterilized_Intact  Sterilized_Neutered  \
# 38180                0                  0                    1
# 38181                0                  1                    0
# 38182                0                  1                    0
# 38183                1                  0                    1
# 38184                0                  1                    0
#
#        Sterilized_Spayed  Sterilized_Unknown  Sex_Female  Sex_Male  \
# 38180                  0                   0           0         1
# 38181                  0                   0           1         0
# 38182                  0                   0           1         0
# 38183                  0                   0           0         1
# 38184                  0                   0           0         1
#
#        Sex_Unknown
# 38180            0
# 38181            0
# 38182            0
# 38183            0
# 38184            0

# %%
# Split dataset to train_x, train_y and test_x

train_x = dataset.loc[0:26728,]

enc = LabelEncoder()
train_y = enc.fit_transform(train['OutcomeType'])
train_y = pd.DataFrame(train_y)

test_x = dataset.loc[26729:38185,]

# %%
train_x.tail()
# Out:
#        AgeuponOutcome  HasName  IsMix  Breed_1  Multiple_Breeds  Color_1  \
# 26724            30.0        0      1       85                0        4
# 26725            90.0        0      1       85                0        4
# 26726          1460.0        1      1      155                0       27
# 26727            28.0        0      1       85                0        2
# 26728           365.0        0      1       85                0        4
#
#        Multiple_Colors  Sterilized_Intact  Sterilized_Neutered  \
# 26724                1                  1                    0
# 26725                0                  0                    0
# 26726                1                  0                    1
# 26727                0                  1                    0
# 26728                1                  1                    0
#
#        Sterilized_Spayed  Sterilized_Unknown  Sex_Female  Sex_Male  \
# 26724                  0                   0           0         1
# 26725                  1                   0           1         0
# 26726                  0                   0           0         1
# 26727                  0                   0           0         1
# 26728                  0                   0           0         1
#
#        Sex_Unknown
# 26724            0
# 26725            0
# 26726            0
# 26727            0
# 26728            0

# %%
train_y.tail()
# Out:
#        0
# 26724  4
# 26725  4
# 26726  0
# 26727  4
# 26728  4

# %%
test_x.tail()
# Out:
#        AgeuponOutcome  HasName  IsMix  Breed_1  Multiple_Breeds  Color_1  \
# 38180            60.0        0      1       85                0        2
# 38181            14.0        0      1       85                0        3
# 38182           365.0        0      1       85                0        6
# 38183          2190.0        1      1      104                0        2
# 38184          1460.0        1      0      131                0        8
#
#        Multiple_Colors  Sterilized_Intact  Sterilized_Neutered  \
# 38180                0                  0                    1
# 38181                0                  1                    0
# 38182                0                  1                    0
# 38183                1                  0                    1
# 38184                0                  1                    0
#
#        Sterilized_Spayed  Sterilized_Unknown  Sex_Female  Sex_Male  \
# 38180                  0                   0           0         1
# 38181                  0                   0           1         0
# 38182                  0                   0           1         0
# 38183                  0                   0           0         1
# 38184                  0                   0           0         1
#
#        Sex_Unknown
# 38180            0
# 38181            0
# 38182            0
# 38183            0
# 38184            0

# %%
# Cross Validation
X_train, X_test, y_train, y_test = cross_validation.train_test_split(train_x.values, train_y[0].values, test_size=0.3, random_state=0)

# %%
#Choose best parameters for randomforest
def best_params(train_x, train_y):
    rfc = RandomForestClassifier()
    param_grid = { 
        'n_estimators': [50, 400],
        'max_features': ['auto', 'sqrt', 'log2']}
    
    CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 5)
    CV_rfc.fit(train_x, train_y)
    return CV_rfc.best_params_

print(best_params(train_x.values, train_y[0].values))
# Out:
# {'max_features': 'log2', 'n_estimators': 400}

# %%
# RandomForest Classifier 

rf = RandomForestClassifier(n_estimators=400, max_features='log2').fit(X_train, y_train)
print('Cross Validation for RandomForestClassifier')
print(rf.score(X_test, y_test))

prediction = pd.DataFrame(rf.predict_proba(test_x.values))
prediction.columns = ['Adoption', 'Died', 'Euthanasia', 'Return_to_owner', 'Transfer']
prediction = pd.concat([test['ID'], prediction], axis=1)
#prediction.to_csv('randomforest.csv', index=False)

prediction.tail()
# Out:
# Cross Validation for RandomForestClassifier
# 0.60294301035
#           ID  Adoption      Died  Euthanasia  Return_to_owner  Transfer
# 11451  11452  0.841691  0.000000    0.000000         0.051795  0.106513
# 11452  11453  0.000000  0.239568    0.000000         0.000000  0.760432
# 11453  11454  0.000000  0.000000    0.042926         0.000000  0.957074
# 11454  11455  0.918256  0.000000    0.000000         0.069065  0.012679
# 11455  11456  0.007500  0.000000    0.041875         0.705625  0.245000

# %%
importances_rf = rf.feature_importances_
importances_rf
# Out:
# array([ 0.31085798,  0.05669454,  0.0114361 ,  0.2575528 ,  0.00824672,
#         0.14748392,  0.01791909,  0.09065142,  0.03023697,  0.03208339,
#         0.01145388,  0.00746582,  0.00752536,  0.01039202])

# %%
features_names = ['AgeuponOutcome','HasName','IsMix','Breed_1','Multiple_Breeds','Color_1','Multiple_Colors','Sterilized_Intact','Sterilized_Neutered','Sterilized_Spayed','Sterilized_Unknown','Sex_Female','Sex_Male','Sex_Unknown']

# %%
pd.Series(importances_rf, index=features_names)
# Out:
# AgeuponOutcome         0.310858
# HasName                0.056695
# IsMix                  0.011436
# Breed_1                0.257553
# Multiple_Breeds        0.008247
# Color_1                0.147484
# Multiple_Colors        0.017919
# Sterilized_Intact      0.090651
# Sterilized_Neutered    0.030237
# Sterilized_Spayed      0.032083
# Sterilized_Unknown     0.011454
# Sex_Female             0.007466
# Sex_Male               0.007525
# Sex_Unknown            0.010392
# dtype: float64

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
pd.Series(importances_rf, index=features_names).plot(kind='bar')

# %%
# XGBClassifier. 

xgboost = XGBClassifier(learning_rate =0.05, n_estimators=500, max_depth=5,
                        min_child_weight=1, gamma=0, subsample=0.8,
                        colsample_bytree=0.8, objective= 'multi:softprob', nthread=4,
                        scale_pos_weight=1, seed=27).fit(X_train, y_train)

print('Cross Validation for XGBClassifier')
print(xgboost.score(X_test, y_test))

prediction = pd.DataFrame(xgboost.predict_proba(test_x.values))
prediction.columns = ['Adoption', 'Died', 'Euthanasia', 'Return_to_owner', 'Transfer']
prediction = pd.concat([test['ID'], prediction], axis=1)

#prediction.to_csv('xgbclassifier_submit.csv', index=False)

prediction.tail()
# Out:
# Cross Validation for XGBClassifier
# 0.64758698092
#           ID  Adoption      Died  Euthanasia  Return_to_owner  Transfer
# 11451  11452  0.877170  0.001321    0.004795         0.010820  0.105893
# 11452  11453  0.000420  0.034163    0.010117         0.001024  0.954276
# 11453  11454  0.002698  0.006849    0.089798         0.003590  0.897065
# 11454  11455  0.303863  0.000389    0.051557         0.510415  0.133776
# 11455  11456  0.015255  0.000989    0.107515         0.467950  0.408291

# %%
importances_xgb = xgboost.feature_importances_
importances_xgb
# Out:
# array([ 0.25230384,  0.0379794 ,  0.03299905,  0.29575485,  0.02620612,
#         0.1778188 ,  0.04538216,  0.03340561,  0.02244545,  0.02151375,
#         0.01287437,  0.02359737,  0.01463613,  0.00308307], dtype=float32)

# %%
# %matplotlib inline

# %%
pd.Series(importances_xgb, index=features_names).plot(kind='bar')

# %%
xgb.plot_importance(xgboost)

# %%
xgb.plot_tree(xgboost, num_trees=2)

# %%
xgb.to_graphviz(xgboost, num_trees=0)
